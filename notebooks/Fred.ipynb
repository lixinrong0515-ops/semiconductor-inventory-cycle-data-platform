# %%
import pandas as pd

# %%
import requests

# %%
api_key = "e090bb15473dcdd368c80d400bc45780"

headers = {
    "Authorization": f"Bearer {api_key}"
}

# %%
api_key = "e090bb15473dcdd368c80d400bc45780"

url = "https://api.stlouisfed.org/fred/series/observations"

params = {
    "api_key": api_key,
    "series_id": "PCU334413334413A",
    "file_type": "json"
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.text[:500])
# Out:
# 200
# {"realtime_start":"2026-08-13","realtime_end":"2026-08-13","observation_start":"1600-01-01","observation_end":"9999-12-31","units":"lin","output_type":1,"file_type":"json","order_by":"observation_date","sort_order":"asc","count":602,"offset":0,"limit":100000,"observations":[{"realtime_start":"2026-08-13","realtime_end":"2026-08-13","date":"1976-06-01","value":"116.5"},{"realtime_start":"2026-08-13","realtime_end":"2026-08-13","date":"1976-07-01","value":"116.0"},{"realtime_start":"2026-08-13","r

# %%
response = requests.get(url, params=params)

response.raise_for_status()

data = response.json()

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['realtime_start', 'realtime_end', 'observation_start', 'observation_end', 'units', 'output_type', 'file_type', 'order_by', 'sort_order', 'count', 'offset', 'limit', 'observations'])

# %%
df = pd.DataFrame(data["observations"])

# %%
df
# Out:
#     realtime_start realtime_end        date   value
# 0       2026-08-13   2026-08-13  1976-06-01   116.5
# 1       2026-08-13   2026-08-13  1976-07-01   116.0
# 2       2026-08-13   2026-08-13  1976-08-01   116.0
# 3       2026-08-13   2026-08-13  1976-09-01   114.7
# 4       2026-08-13   2026-08-13  1976-10-01   114.7
# ..             ...          ...         ...     ...
# 597     2026-08-13   2026-08-13  2026-03-01  55.393
# 598     2026-08-13   2026-08-13  2026-04-01  55.943
# 599     2026-08-13   2026-08-13  2026-05-01  54.092
# 600     2026-08-13   2026-08-13  2026-06-01  51.942
# 601     2026-08-13   2026-08-13  2026-07-01  51.918
#
# [602 rows x 4 columns]
